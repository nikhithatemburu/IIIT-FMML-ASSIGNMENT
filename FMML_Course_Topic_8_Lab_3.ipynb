# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhithatemburu/IIIT-FMML-ASSIGNMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-26 14:50:16--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  60.0MB/s    in 1.2s
#
# 2024-03-26 14:50:18 (60.0 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# With the assumptions that the features contribute equally to the result and that they are independent, we can begin by considering a simple classification model based on these assumptions. One common model that fits these criteria is the Naive Bayes classifier.
#
# The Naive Bayes classifier assumes that features are conditionally independent given the class label. This means that the presence of one feature does not affect the presence of another feature, given the class label.
#
# Here's a general overview of how the Naive Bayes classifier works under these assumptions:
#
# Training Phase:
#
# Calculate the prior probabilities of each class based on the training data.
# For each feature, calculate the conditional probabilities of observing each value of the feature given each class.
# Prediction Phase:
#
# Given a new instance with feature values, calculate the posterior probability of each class using Bayes' theorem and the conditional independence assumption.
# Assign the class label with the highest posterior probability as the predicted class for the instance.
# The independence assumption simplifies the calculation of conditional probabilities, as we can treat each feature's probability distribution separately.
#
# While Naive Bayes is a simplistic model, it can work well in practice, especially with large datasets and when the independence assumption roughly holds. However, it's important to note that in real-world scenarios, features often exhibit some level of dependence, and more sophisticated models may be necessary to capture these relationships accurately. Nonetheless, Naive Bayes serves as a good starting point for classification tasks, particularly when computational efficiency is a concern or when interpretability is important.

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 6556   1703.03020v3  Exploiting the wealth of imaging and non-imagi...  stat
# 10441   1101.1057v3  We consider the problem of online linear regre...  stat
# 14253   1311.2694v2  Community detection in networks is a key explo...  stat
# 40658   1207.4149v1  We present new MCMC algorithms for computing t...  stat
# 14326   0707.0808v1  We have used a simple camera phone to signific...    cs
# ...             ...                                                ...   ...
# 19324   1304.3418v1  We propose an inequality paradigm for probabil...    cs
# 30979  1802.00176v1  This paper proposes perceptual compressive sen...    cs
# 14161  1802.02026v1  Reservoir computing is a bio-inspired computin...    cs
# 13727   1312.4149v1  Recently, with the rapid development of techno...    cs
# 40773   1401.0159v1  This is an overview paper written in style of ...    cs
#
#                                                    title  year  \
# 6556   Spectral Graph Convolutions for Population-bas...  2017
# 10441  Sparsity regret bounds for individual sequence...  2011
# 14253  Hypothesis Testing for Automated Community Det...  2013
# 40658                               From Fields to Trees  2012
# 14326  The Cyborg Astrobiologist: Porting from a wear...  2007
# ...                                                  ...   ...
# 19324  An Inequality Paradigm for Probabilistic Knowl...  2013
# 30979                     Perceptual Compressive Sensing  2018
# 14161  Brain-inspired photonic signal processor for p...  2018
# 13727       Autonomous Quantum Perceptron Neural Network  2013
# 40773  Speeding-Up Convergence via Sequential Subspac...  2013
#
#                                                 keywords
# 6556   [exploiting, information, prediction, represen...
# 10441  [regression, arbitrary, deterministic, sequenc...
# 14253  [community, detection, exploratory, applicatio...
# 40658  [algorithms, computing, posterior, distributio...
# 14326  [significantly, exploration, astrobiology, alg...
# ...                                                  ...
# 19324  [inequality, probabilistic, reasoning, conditi...
# 30979  [perceptual, compressive, convolutional, measu...
# 14161  [reservoir, computing, computing, processing, ...
# 13727  [development, technology, applications, comput...
# 40773  [introduced, framework, unconstrained, optimiz...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 6556     [exploiting, information, prediction, represen...
# 10441    [regression, arbitrary, deterministic, sequenc...
# 14253    [community, detection, exploratory, applicatio...
# 40658    [algorithms, computing, posterior, distributio...
# 14326    [significantly, exploration, astrobiology, alg...
#                                ...
# 10343    [unsupervised, estimation, fundamental, applic...
# 17843    [authorship, verification, investigate, docume...
# 33293    [forecasting, dependent, parameters, temperatu...
# 28824    [reference, assessment, synthetically, generat...
# 26655    [increasing, convolutional, rewarding, perform...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8754 words.
# Out of those 4522 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9345bde1-ae17-42c9-87d4-0c3c1a46b6ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9345bde1-ae17-42c9-87d4-0c3c1a46b6ae")) {                    Plotly.newPlot(                        "9345bde1-ae17-42c9-87d4-0c3c1a46b6ae",                        [{"x":["prediction","representing","populations","combining","associated","potentially","framework","databases","outperforming","convolutional","convolutions","considered","partially","predictions","characteristics","performance","contextual","introduce","exploiting","phenotypic","similarities","demonstrate","unlabelled","challenging","individual","associations","information","similarity","interaction","structure","significantly","approaches","represent","population","integrating","classification","modelling","potential","classifiers","conversion","parameter","regression","dimension","exponential","questions","weighting","algorithm","arbitrary","truncation","logarithmic","deterministic","counterpart","particular","stochastic","sequences","community","unlabeled","identifying","principal","detection","overlapping","biological","distribution","communities","automated","establish","attention","determine","exploratory","knowledge","automatically","statistics","hypothesis","clustering","recursive","blockmodel","applications","theoretically","outperforms","probabilistic","algorithms","adjacency","generated","contribution","eigenvalue","quantifiable","different","conditioning","partitioned","empirically","variables","undirected","construct","posterior","correlation","demonstration","propagation","theoretical","efficient","comparing","distributions","expectations","computing","partitioning","solutions","considerably","remaining","graphical","astrobiologist","planetary","exploration","corrective","traditional","regularized","underlying","nonlinear","functions","determining","applicable","resulting","simulations","statistical","synthetic","interested","conducted","replacement","asymptotic","application","motivated","understand","measurement","extensive","adaptation","literature","simulation","phenomenon","registration","contamination","formulation","including","established","improvement","substantial","sequential","resorting","coalescent","significant","particularly","incorporate","quadratic","artificial","approximation","hierarchical","reduction","improvements","byproduct","appropriate","continuous","complexity","computational","approximations","techniques","quantization","suitability","especially","inappropriate","inference","factorization","conventional","compression","recurrent","decomposition","characterized","derivation","addressing","estimation","principles","probability","parameterized","advantage","parameters","averaging","optimizing","covariance","magnitude","conceptual","comparison","determines","reinforcement","iteratively","discussion","algorithmic","linearizing","specifically","asymptotically","membership","threshold","numerical","detectability","extensions"],"y":[223,75,11,102,106,47,557,47,28,407,15,124,41,92,100,877,40,333,72,1,21,516,6,255,115,11,664,126,93,317,267,421,106,44,38,489,51,174,132,17,116,115,60,42,69,29,820,93,0,18,38,9,274,134,103,65,53,60,44,340,28,42,228,16,107,44,169,72,5,341,167,74,54,142,23,1,454,23,246,143,575,2,174,75,8,1,741,14,6,78,142,10,86,31,80,14,67,147,390,74,119,6,137,20,168,25,20,62,2,3,55,3,157,34,120,52,224,34,59,144,42,142,144,20,67,7,24,235,60,68,37,178,69,119,79,20,16,1,88,254,42,145,52,79,6,1,240,67,63,31,147,109,103,80,116,4,77,94,216,272,34,399,19,8,128,2,214,33,111,35,146,66,33,17,26,204,23,150,18,88,246,26,45,23,50,26,132,17,111,35,23,44,1,160,10,20,33,88,1,34],"type":"bar"},{"x":["prediction","representing","populations","combi ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4522,), (4522, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8108333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Aspartame</span> <span style=''>Solving</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Constraint</span> <span style='background-color:rgba(0, 255, 0, 0.826086956521739);'>Satisfaction</span> <span style=''>Problems</span> <span style=''>with</span> <span style=''>Answer</span> <span style=''>Set</span> <span style='background-color:rgba(0, 255, 0, 0.4628571428571429);'>Programming</span> <br/><br/><span style=''>Encoding</span> <span style=''>finite</span> <span style=''>linear</span> <span style=''>CSPs</span> <span style=''>as</span> <span style=''>Boolean</span> <span style=''>formulas</span> <span style=''>and</span> <span style=''>solving</span> <span style=''>them</span> <span style=''>by</span> <span style=''>using</span> <span style=''>modern</span> <span style=''>SAT</span> <span style=''>solvers</span> <span style=''>has</span> <span style=''>proven</span> <span style=''>to</span> <span style=''>be</span> <span style=''>highly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>effective</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666666);'>exemplified</span> <span style=''>by</span> <span style=''>the</span> <span style=''>award</span> <span style=''>winning</span> <span style=''>sugar</span> <span style=''>system</span> <span style=''>We</span> <span style=''>here</span> <span style=''>develop</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternative</span> <span style=''>approach</span> <span style=''>based</span> <span style=''>on</span> <span style=''>ASP</span> <span style=''>This</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>use</span> <span style=''>first</span> <span style=''>order</span> <span style='background-color:rgba(0, 255, 0, 0.8333333333333333);'>encodings</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>providing</span> <span style=''>us</span> <span style=''>with</span> <span style=''>a</span> <span style=''>high</span> <span style=''>degree</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>flexibility</span> <span style=''>for</span> <span style=''>easy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experimentation</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.324396782841823);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implementations</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resulting</span> <span style=''>system</span> <span style=''>aspartame</span> <span style=''>re</span> <span style=''>uses</span> <span style=''>parts</span> <span style=''>of</span> <span style=''>sugar</span> <span style=''>for</span> <span style=''>parsing</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>normalizing</span> <span style=''>CSPs</span> <span style=''>The</span> <span style=''>obtained</span> <span style=''>set</span> <span style=''>of</span> <span style=''>facts</span> <span style=''>is</span> <span style=''>then</span> <span style=''>combined</span> <span style=''>with</span> <span style=''>an</span> <span style=''>ASP</span> <span style=''>encoding</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>grounded</span> <span style=''>and</span> <span style=''>solved</span> <span style=''>by</span> <span style=''>off</span> <span style=''>the</span> <span style=''>shelf</span> <span style=''>ASP</span> <span style=''>systems</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.37142857142857144);'>establish</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>competitiveness</span> <span style=''>of</span> <span style=''>our</span> <span style=''>approach</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Asymptotic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generalization</span> <span style=''>Bound</span> <span style=''>of</span> <span style=''>Fishers</span> <span style=''>Linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Discriminant</span> <span style=''>Analysis</span> <br/><br/><span style=''>Fishers</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discriminant</span> <span style=''>analysis</span> <span style=''>(FLDA)</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>method</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>pattern</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recognition</span> <span style=''>It</span> <span style=''>has</span> <span style=''>been</span> <span style=''>shown</span> <span style=''>that</span> <span style=''>FLDA</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>asymptotically</span> <span style=''>Bayes</span> <span style=''>optimal</span> <span style=''>under</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>homoscedastic</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>However</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classical</span> <span style=''>result</span> <span style=''>has</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>following</span> <span style=''>two</span> <span style=''>major</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>limitations</span> <span style=''>1)</span> <span style=''>it</span> <span style=''>holds</span> <span style=''>only</span> <span style=''>for</span> <span style=''>a</span> <span style=''>fixed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style=''>D</span> <span style=''>and</span> <span style=''>thus</span> <span style=''>does</span> <span style=''>not</span> <span style=''>apply</span> <span style=''>when</span> <span style=''>D</span> <span style=''>and</span> <span style=''>the</span> <span style=''>training</span> <span style=''>sample</span> <span style=''>size</span> <span style=''>N</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>proportionally</span> <span style=''>large</span> <span style=''>2)</span> <span style=''>it</span> <span style=''>does</span> <span style=''>not</span> <span style=''>provide</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>quantitative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>description</span> <span style=''>on</span> <span style=''>how</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>ability</span> <span style=''>of</span> <span style=''>FLDA</span> <span style=''>is</span> <span style=''>affected</span> <span style=''>by</span> <span style=''>D</span> <span style=''>and</span> <span style=''>N</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>asymptotic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>FLDA</span> <span style=''>based</span> <span style=''>on</span> <span style=''>random</span> <span style=''>matrix</span> <span style=''>theory</span> <span style=''>in ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Implicit</span> <span style=''>Density</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Estimation</span> <span style=''>by</span> <span style=''>Local</span> <span style=''>Moment</span> <span style=''>Matching</span> <span style=''>to</span> <span style=''>Sample</span> <span style=''>from</span> <span style=''>Auto</span> <span style=''>Encoders</span> <br/><br/><span style=''>Recent</span> <span style=''>work</span> <span style=''>suggests</span> <span style=''>that</span> <span style=''>some</span> <span style=''>auto</span> <span style=''>encoder</span> <span style=''>variants</span> <span style=''>do</span> <span style=''>a</span> <span style=''>good</span> <span style=''>job</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3090909090909091);'>capturing</span> <span style=''>the</span> <span style=''>local</span> <span style=''>manifold</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>the</span> <span style=''>unknown</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.34193548387096767);'>generating</span> <span style=''>density</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contributes</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>mathematical</span> <span style='background-color:rgba(0, 255, 0, 0.34920634920634924);'>understanding</span> <span style=''>of</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>phenomenon</span> <span style=''>and</span> <span style=''>helps</span> <span style=''>define</span> <span style=''>better</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>justified</span> <span style=''>sampling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>based</span> <span style=''>on</span> <span style=''>auto</span> <span style=''>encoder</span> <span style=''>variants</span> <span style=''>We</span> <span style=''>consider</span> <span style=''>an</span> <span style=''>MCMC</span> <span style=''>where</span> <span style=''>each</span> <span style=''>step</span> <span style=''>samples</span> <span style=''>from</span> <span style=''>a</span> <span style=''>Gaussian</span> <span style=''>whose</span> <span style=''>mean</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.6319999999999999);'>covariance</span> <span style=''>matrix</span> <span style=''>depend</span> <span style=''>on</span> <span style=''>the</span> <span style=''>previous</span> <span style=''>state</span> <span style=''>defines</span> <span style=''>through</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.5636363636363636);'>asymptotic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>a</span> <span style=''>target</span> <span style=''>density</span> <span style=''>First</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>good</span> <span style=''>choices</span> <span style=''>(in</span> <span style=''>the</span> <span style=''>sense</span> <span style=''>of</span> <span style=''>consistency)</span> <span style=''>for</span> <span style=''>these</span> <span style=''>mean</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.6319999999999999);'>covariance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>are</span> <span style=''>the</span> <span style=''>local</span> <span style=''>expected</span> <span style=''>value</span> <span style=''>and</span> <span style=''>local</span> <span style='background-color:rgba(255, 0, 0, 0.6319999999999999);'>covariance</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Optimal</span> <span style=''>Data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Collection</span> <span style=''>For</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Informative</span> <span style=''>Rankings</span> <span style=''>Expose</span> <span style=''>Well</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Connected</span> <span style=''>Graphs</span> <br/><br/><span style=''>Given</span> <span style=''>a</span> <span style=''>graph</span> <span style=''>where</span> <span style=''>vertices</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternatives</span> <span style=''>and</span> <span style=''>arcs</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represent</span> <span style=''>pairwise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparison</span> <span style=''>data</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>ranking</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>to</span> <span style=''>find</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potential</span> <span style=''>function</span> <span style=''>defined</span> <span style=''>on</span> <span style=''>the</span> <span style=''>vertices</span> <span style=''>such</span> <span style=''>that</span> <span style=''>the</span> <span style=''>gradient</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potential</span> <span style=''>function</span> <span style=''>agrees</span> <span style=''>with</span> <span style=''>the</span> <span style=''>pairwise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparisons</span> <span style=''>Our</span> <span style=''>goal</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>is</span> <span style=''>to</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collecting</span> <span style=''>data</span> <span style=''>for</span> <span style=''>which</span> <span style=''>the</span> <span style=''>least</span> <span style=''>squares</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>for</span> <span style=''>the</span> <span style=''>ranking</span> <span style=''>problem</span> <span style=''>has</span> <span style=''>maximal</span> <span style=''>Fisher</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimental</span> <span style=''>design</span> <span style=''>is</span> <span style=''>to</span> <span style=''>view</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collection</span> <span style=''>as</span> <span style=''>a</span> <span style=''>bi</span> <span style=''>level</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>where</span> <span style=''>the</span> <span style=''>inner</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>the</span> <span style=''>ranking</span> <span style=''>problem</span> <span style=''>and</span> <span style=''>the</span> <span style=''>outer</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>to</span> <span style=''>identify</span> <span style=''>data</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maximizes</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>informativeness</span> <span style=''>of</span> ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12257368799424874)
# 	automatic (0.0682961897915169)
# 	experimental (0.13048166786484544)
# 	information (0.23867721063982747)
# 	representation (0.13371675053918045)
# 	segmentation (0.07764198418404025)
# 	detection (0.12221423436376708)
# 	different (0.26635514018691586)
# 	recognition (0.13695183321351545)
# 	convolutional (0.14629762760603882)
#
# Some Statistics words are:
# 	variables (0.1303270564915758)
# 	stochastic (0.12933597621407333)
# 	distribution (0.18037661050545095)
# 	statistical (0.1506442021803766)
# 	algorithm (0.3949454905847374)
# 	theoretical (0.1531219028741328)
# 	estimation (0.17492566897918732)
# 	inference (0.19226957383548068)
# 	dimensional (0.17789890981169476)
# 	regression (0.18285431119920714)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="80d23d91-c46c-4436-a387-e3780c2d5eaa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("80d23d91-c46c-4436-a387-e3780c2d5eaa")) {                    Plotly.newPlot(                        "80d23d91-c46c-4436-a387-e3780c2d5eaa",                        [{"x":["prediction","representing","populations","combining","associated","potentially","framework","databases","outperforming","convolutional","convolutions","considered","partially","predictions","characteristics","performance","contextual","introduce","exploiting","phenotypic","similarities","demonstrate","unlabelled","challenging","individual","associations","information","similarity","interaction","structure","significantly","approaches","represent","population","integrating","classification","modelling","potential","classifiers","conversion","parameter","regression","dimension","exponential","questions","weighting","algorithm","arbitrary","truncation","logarithmic","deterministic","counterpart","particular","stochastic","sequences","community","unlabeled","identifying","principal","detection","overlapping","biological","distribution","communities","automated","establish","attention","determine","exploratory","knowledge","automatically","statistics","hypothesis","clustering","recursive","blockmodel","applications","theoretically","outperforms","probabilistic","algorithms","adjacency","generated","contribution","eigenvalue","quantifiable","different","conditioning","partitioned","empirically","variables","undirected","construct","posterior","correlation","demonstration","propagation","theoretical","efficient","comparing","distributions","expectations","computing","partitioning","solutions","considerably","remaining","graphical","astrobiologist","planetary","exploration","corrective","traditional","regularized","underlying","nonlinear","functions","determining","applicable","resulting","simulations","statistical","synthetic","interested","conducted","replacement","asymptotic","application","motivated","understand","measurement","extensive","adaptation","literature","simulation","phenomenon","registration","contamination","formulation","including","established","improvement","substantial","sequential","resorting","coalescent","significant","particularly","incorporate","quadratic","artificial","approximation","hierarchical","reduction","improvements","byproduct","appropriate","continuous","complexity","computational","approximations","techniques","quantization","suitability","especially","inappropriate","inference","factorization","conventional","compression","recurrent","decomposition","characterized","derivation","addressing","estimation","principles","probability","parameterized","advantage","parameters","averaging","optimizing","covariance","magnitude","conceptual","comparison","determines","reinforcement","iteratively","discussion","algorithmic","linearizing","specifically","asymptotically","membership","threshold","numerical","detectability","extensions","independently","thresholds","fundamental","equations","characteristic","dictionary","emphasize","undesirable","stability","demonstrated","unfortunately","increases","convergence","experiments","dramatically","operating","splitting","requirement","identification","reproducing","analytical","superiority","discarding","strategies","regularization","environment","filtering","dimensional","prohibitive","posteriori","perturbed","concentration","perturbations","maximizing","inequalities","involving","perturbation","generating","estimations","approximate","providing","topological","multidimensional","leveraging","contribute","robustness","increased","difficult","diversity","dimensionality","favorably","ensembles","multiscale ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	truncation
# 	dobrushins
# 	inhomogeneity
# 	quadrature
# 	exposition
# 	montanari
# 	collapsed
# 	correntropy
# 	cytometry
# 	mimicking
# 	pseudolikelihood
# 	diarization
# 	submanifold
# 	instantiating
# 	unpenalized
# 	nullspace
# 	suboptimality
# 	individualized
# 	dendrogram
# 	particulars
# Some words which never appear in Statistics papers:
# 	astrobiologist
# 	hippocampus
# 	attentional
# 	apartments
# 	bilingual
# 	judgement
# 	transposition
# 	keypoints
# 	disguises
# 	undefined
# 	vehicular
# 	halfspaces
# 	plasticity
# 	izhikevich
# 	solomonoff
# 	recognizer
# 	discourse
# 	comprehend
# 	reactions
# 	broadcast

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.091954733782698e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.78
